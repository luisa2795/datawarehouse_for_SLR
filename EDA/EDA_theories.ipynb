# %%
#import packages
import pandas as pd
import os

#define source directory
path='/home/muellerrol/causeminer2/reports/2021_11_09_103116_results'

#filenames of theory-related files
theo_file='theories.csv'

#load data
theo=pd.read_csv(os.path.join(path,theo_file))

print(theo.shape)
print(theo.columns)
# Out:
# (24744, 20)
# Index(['article_id', 'para_id', 'sentence_start', 'sentence_id',
#        'journal_akronym', 'last_section_title', 'last_subsection_title',
#        'sentence_type', 'sentence', 'entity', 'ent_id', 'ent_path', 'level_1',
#        'level_2', 'level_3', 'level_4', 'level_5', 'level_6', 'level_7',
#        'level_8'],
#       dtype='object')

# %%
theo.head()
# Out:
#    article_id para_id  sentence_start  sentence_id journal_akronym  \
# 0           1    1_12            1434  1_1434_1457            JSIS
# 1           2     2_7             963    2_963_997            JSIS
# 2           2     2_7            1080  2_1080_1135            JSIS
# 3           2    2_13            1378  2_1378_1398            JSIS
# 4           2    2_16            2043  2_2043_2074            JSIS
#
#                                   last_section_title last_subsection_title  \
# 0         Firm - hosted online branding communities                    NaN
# 1            Decision - making within organizations                    NaN
# 2            Decision - making within organizations                    NaN
# 3                        Political Decision Process                    NaN
# 4  Some observations on the decision - support pa...                   NaN
#
#   sentence_type                                           sentence  \
# ...
