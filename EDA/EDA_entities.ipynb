# %%
#import packages
import pandas as pd

#load data
ent=pd.read_csv('C:/Users/luisa/Documents/BIPM_2/DWH4SLR/reports/entities.csv')

ent.head()
# Out:
# C:\Users\luisa\anaconda3\lib\site-packages\IPython\core\interactiveshell.py:3146: DtypeWarning: Columns (20) have mixed types.Specify dtype option on import or set low_memory=False.
#   has_raised = await self.run_ast_nodes(code_ast.body, cell_name,
#    article_id para_id  sentence_start sentence_id journal_akronym  \
# 0           1     1_7             508   1_508_561             AMJ
# 1           1     1_7             594   1_594_627             AMJ
# 2           1     1_7             627   1_627_722             AMJ
# 3           1     1_7             627   1_627_722             AMJ
# 4           1     1_7             738   1_738_761             AMJ
#
#   last_section_title last_subsection_title sentence_type  \
# 0      Completeness                    NaN     PARAGRAPH
# 1      Completeness                    NaN     PARAGRAPH
# 2      Completeness                    NaN     PARAGRAPH
# 3      Completeness                    NaN     PARAGRAPH
# ...

# %%
ent.columns
# Out:
# Index(['article_id', 'para_id', 'sentence_start', 'sentence_id',
#        'journal_akronym', 'last_section_title', 'last_subsection_title',
#        'sentence_type', 'sentence', 'entity', 'label', 'ent_id', 'ent_path',
#        'level_1', 'level_2', 'level_3', 'level_4', 'level_5', 'level_6',
#        'level_7', 'level_8'],
#       dtype='object')
