# %%
#import packages
import pandas as pd
import pandas_profiling
import numpy as np

#load data
ent=pd.read_csv('C:/Users/luisa/Documents/BIPM_2/DWH4SLR/reports/entities.csv', dtype={
    'article_id': int, 'para_id': "string", 'sentence_start': int, 'sentence_id': "string", 'journal_akronym': "string", 'last_section_title': "string",
    'last_subsection_title': "string", 'sentence_type': "string", 'sentence': "string", 'entity': "string", 'label': "string", 'ent_id': "string",
    'ent_path': "string", 'level_1': "string", 'level_2': "string", 'level_3': "string", 'level_4': "string", 'level_5': "string", 'level_6': "string",
    'level_7': "string", 'level_8': "string"})

ent.head()
# Out:
#    article_id para_id  sentence_start sentence_id journal_akronym  \
# 0           1     1_7             508   1_508_561             AMJ
# 1           1     1_7             594   1_594_627             AMJ
# 2           1     1_7             627   1_627_722             AMJ
# 3           1     1_7             627   1_627_722             AMJ
# 4           1     1_7             738   1_738_761             AMJ
#
#   last_section_title last_subsection_title sentence_type  \
# 0      Completeness                   <NA>     PARAGRAPH
# 1      Completeness                   <NA>     PARAGRAPH
# 2      Completeness                   <NA>     PARAGRAPH
# 3      Completeness                   <NA>     PARAGRAPH
# 4      Completeness                   <NA>     PARAGRAPH
#
#                                             sentence            entity  ...  \
# 0  In the review of our decision letters , perhap...        constructs  ...
# ...

# %%
ent.columns
# Out:
# Index(['article_id', 'para_id', 'sentence_start', 'sentence_id',
#        'journal_akronym', 'last_section_title', 'last_subsection_title',
#        'sentence_type', 'sentence', 'entity', 'label', 'ent_id', 'ent_path',
#        'level_1', 'level_2', 'level_3', 'level_4', 'level_5', 'level_6',
#        'level_7', 'level_8'],
#       dtype='object')

# %%
#load data
ent_count=pd.read_csv('C:/Users/luisa/Documents/BIPM_2/DWH4SLR/reports/entity_count_per_paper.csv')

ent_count.head()
# Out:
#    article_id                  ent_id  \
# 0           1       archival research
# 1           1               construct
# 2           1  individual participant
# 3           1      dependent variable
# 4           1              experiment
#
#                                             ent_path              label  \
# 0  data collection method/empirical qualitative m...  COLLECTION_METHOD
# 1                            model element/construct      MODEL_ELEMENT
# 2                 participant/individual participant       PARTICIPANTS
# 3          model element/variable/dependent variable      MODEL_ELEMENT
# 4  data collection method/empirical quantitative ...  COLLECTION_METHOD
#
#                   level_1                        level_2             level_3  \
# 0  data collection method   empirical qualitative method   archival research
# 1           model element                      construct                 NaN
# ...

# %%
ent_count.columns
# Out:
# Index(['article_id', 'ent_id', 'ent_path', 'label', 'level_1', 'level_2',
#        'level_3', 'level_4', 'level_5', 'level_6', 'level_7', 'level_8',
#        'count'],
#       dtype='object')

# %%
#pandas_profiling.ProfileReport(ent)

ent.info
# Out:
# <bound method DataFrame.info of          article_id    para_id  sentence_start        sentence_id  \
# 0                 1        1_7             508          1_508_561
# 1                 1        1_7             594          1_594_627
# 2                 1        1_7             627          1_627_722
# 3                 1        1_7             627          1_627_722
# 4                 1        1_7             738          1_738_761
# ...             ...        ...             ...                ...
# 6604363       50959  50959_123           10301  50959_10301_10313
# 6604364       50959  50959_123           10321  50959_10321_10324
# 6604365       50959  50959_123           10359  50959_10359_10375
# 6604366       50959  50959_123           10359  50959_10359_10375
# 6604367       50959  50959_128           10622  50959_10622_10634
#
#         journal_akronym last_section_title last_subsection_title  \
# 0                   AMJ      Completeness                   <NA>
# ...

# %%
pandas_profiling.ProfileReport(ent)
# Out:
# Summarize dataset:  12%|█▏        | 3/26 [02:41<20:40, 53.91s/it, Describe variable:journal_akronym]
# ---------------------------------------------------------------------------
# MemoryError                               Traceback (most recent call last)
# ~\anaconda3\envs\thesis\lib\site-packages\IPython\core\formatters.py in __call__(self, obj)
#     343             method = get_real_method(obj, self.print_method)
#     344             if method is not None:
# --> 345                 return method()
#     346             return None
#     347         else:
#
# ~\anaconda3\envs\thesis\lib\site-packages\pandas_profiling\profile_report.py in _repr_html_(self)
#     416     def _repr_html_(self) -> None:
#     417         """The ipython notebook widgets user interface gets called by the jupyter notebook."""
# --> 418         self.to_notebook_iframe()
#     419
#     420     def __repr__(self) -> str:
#
# ...
