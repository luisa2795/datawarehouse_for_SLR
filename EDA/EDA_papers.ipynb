# %%
#import packages
import pandas as pd
import os

#define source directory
path='/home/muellerrol/causeminer2/reports/2021_11_09_103116_results'
sourcepath='/home/muellerrol/causeminer2/reports/2021_12_06_153039_results'

#filenames of paper-related files
pap_file='papers.csv'
pap_fin_file='papers_final.csv'

#load data
#pap=pd.read_csv(os.path.join(path,pap_file))
#pap_fin=pd.read_csv(os.path.join(path,pap_fin_file))
pap_new=pd.read_csv(os.path.join(sourcepath,'papers_final.csv'))

#print(pap.shape)
#print(pap.columns)

#print(pap_fin.shape)
#print(pap_fin.columns)

print(pap_new.shape)
print(pap_new.columns)
# Out:
# (7479, 14)
# Index(['article_id', 'citekey', 'journal_akronym', 'journal', 'year',
#        'authors', 'title', 'abstract', 'keywords', 'number_of_pages', 'volume',
#        'issue', 'publisher', 'place'],
#       dtype='object')

# %%
pap_new.head()
# Out:
#    article_id                                            citekey  \
# 0           1  (kevin)_yan_j_examining_interdependence_betwee...
# 1           2  a_wilson_f_computer_support_for_strategic_orga...
# 2           3  aaen_i_essence_facilitating_software_innovatio...
# 3           4  aakhus_m_symbolic_action_research_in_informati...
# 4           5  aaltonen_a_everything_counts_in_large_amounts_...
#
#   journal_akronym                                       journal  year  \
# 0            JSIS  The Journal Of Strategic Information Systems  2021
# 1            JSIS  The Journal Of Strategic Information Systems  1994
# 2            EJIS       European Journal Of Information Systems  2008
# 3            MISQ                                 Mis Quarterly  2014
# 4             JIT             Journal Of Information Technology  2014
#
#                                              authors  \
# 0  (Kevin) Yan, J.; Leidner, D.; Benbya, H.; Zou, W.
# ...

# %%
pap_new[['journal_akronym', 'journal', 'volume', 'issue', 'publisher', 'place']]#.drop_duplicates()
# Out:
#      journal_akronym                                            journal  \
# 0               JSIS       The Journal Of Strategic Information Systems
# 1               JSIS       The Journal Of Strategic Information Systems
# 2               EJIS            European Journal Of Information Systems
# 3               MISQ                                      Mis Quarterly
# 4                JIT                  Journal Of Information Technology
# ...              ...                                                ...
# 7474            JAIS  Journal Of The Association For Information Sys...
# 7475            JMIS          Journal Of Management Information Systems
# 7476             JIT                  Journal Of Information Technology
# 7477            MISQ                                      Mis Quarterly
# 7478             JIT                  Journal Of Information Technology
#
#       volume issue  publisher  place
# 0       30.0   1.0        NaN    NaN
# ...

# %%
pap.head()
# Out:
#    article_id                                            citekey  \
# 0           1  (kevin)_yan_j_examining_interdependence_betwee...
# 1           2  a_wilson_f_computer_support_for_strategic_orga...
# 2           3  aaen_i_essence_facilitating_software_innovatio...
# 3           4  aakhus_m_symbolic_action_research_in_informati...
# 4           5  aaltonen_a_everything_counts_in_large_amounts_...
#
#                                         filename_xml journal_akronym  \
# 0  (Kevin) YanJ#LeidnerD#BenbyaH#ZouW_2021_Examin...            JSIS
# 1  A WilsonF_1994_Computer support for strategic ...            JSIS
# 2  AaenI_2008_Essence - facilitating software inn...            EJIS
# 3  AakhusM#ÅgerfalkP#LyytinenK#Te'eniD_2014_Symbo...            MISQ
# 4  AaltonenA#TempiniN_2014_Everything counts in l...             JIT
#
#                                         journal  year  \
# 0  The Journal Of Strategic Information Systems  2021
# ...

# %%
pap_fin.head()
# Out:
#    article_id                                            citekey  \
# 0           1  (kevin)_yan_j_examining_interdependence_betwee...
# 1           2  a_wilson_f_computer_support_for_strategic_orga...
# 2           3  aaen_i_essence_facilitating_software_innovatio...
# 3           4  aakhus_m_symbolic_action_research_in_informati...
# 4           5  aaltonen_a_everything_counts_in_large_amounts_...
#
#   journal_akronym  year                                            authors  \
# 0            JSIS  2021  (Kevin) Yan, J.; Leidner, D.; Benbya, H.; Zou, W.
# 1            JSIS  1994                                       A Wilson, F.
# 2            EJIS  2008                                           Aaen, I.
# 3            MISQ  2014  Aakhus, M.; Ågerfalk, P.; Lyytinen, K.; Te'eni...
# 4             JIT  2014                          Aaltonen, A.; Tempini, N.
#
#                                                title  \
# 0  Examining interdependence between product user...
# ...

# %%
pap.authors.isna().value_counts()
# Out:
# False    7385
# True       94
# Name: authors, dtype: int64
