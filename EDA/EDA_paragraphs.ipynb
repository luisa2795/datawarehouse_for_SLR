# %%
#import packages
import pandas as pd
import os

#define source directory
path='/home/muellerrol/causeminer2/reports/2021_11_09_103116_results'

#filenames of paragraph-related files
para_file='paragraphs.csv'

#load data
para=pd.read_csv(os.path.join(path,para_file))

print(para.shape)
print(para.columns)
# Out:
# (876976, 10)
# Index(['para_id', 'article_id', 'section_nr', 'last_section_title',
#        'last_subsection_title', 'paragraph_type', 'number_of_citations',
#        'paragraph', 'paragraph_with_cite', 'has_citation'],
#       dtype='object')

# %%
para.head()
# Out:
#   para_id  article_id  section_nr last_section_title last_subsection_title  \
# 0     1_0           1           0                NaN                   NaN
# 1     1_1           1           0           Abstract                   NaN
# 2     1_2           1           1      Introduction                    NaN
# 3     1_3           1           1      Introduction                    NaN
# 4     1_4           1           1      Introduction                    NaN
#
#   paragraph_type  number_of_citations  \
# 0      PARAGRAPH                    0
# 1       ABSTRACT                    0
# 2         HEADER                    0
# 3      PARAGRAPH                    5
# 4      PARAGRAPH                    3
#
#                                            paragraph  \
# 0  Examining interdependence between product user...
# 1  A B S T R A C TFirm - sponsored online user co...
# 2                                      Introduction
# 3  Firm - hosted online user communities ( herein...
# ...
