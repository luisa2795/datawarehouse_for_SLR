# %%
#import packages
import pandas as pd

#load data
sent=pd.read_csv('C:/Users/luisa/Documents/BIPM_2/DWH4SLR/reports/sentences.csv')
con_sent=pd.read_csv('C:/Users/luisa/Documents/BIPM_2/DWH4SLR/reports/contruct_sentences.csv')

print("sentences:")
print(sent.head())
print("construct sencences:")
print(con_sent.head())
# Out:
# sentences:
#    article_id sentence_id para_id            sentence  section_nr  \
# 0           1       1_0_1     1_0                               0
# 1           1       1_1_2     1_0     START_TITLE_TAG           0
# 2           1       1_2_3     1_0                               0
# 3           1       1_3_4     1_1  START_ABSTRACT_TAG           0
# 4           1       1_4_5     1_1                               0
#
#   last_section_title last_subsection_title sentence_type references  \
# 0                NaN                   NaN         EMPTY         []
# 1                NaN                   NaN           TAG         []
# 2                NaN                   NaN     PARAGRAPH         []
# 3                NaN                   NaN           TAG         []
# 4           Abstract                   NaN      ABSTRACT         []
#
#    number_of_citations
# 0                    0
# 1                    0
# 2                    0
# 3                    0
# ...

# %%
sent.columns
# Out:
# Index(['article_id', 'sentence_id', 'para_id', 'sentence', 'section_nr',
#        'last_section_title', 'last_subsection_title', 'sentence_type',
#        'references', 'number_of_citations'],
#       dtype='object')

# %%
sent.iloc[200:210,:]
# Out:
#      article_id  sentence_id para_id  \
# 200           1  1_3322_3352    1_24
# 201           1  1_3352_3372    1_24
# 202           1  1_3372_3420    1_24
# 203           1  1_3420_3421    1_24
# 204           1  1_3421_3422    1_24
# 205           1  1_3422_3423    1_25
# 206           1  1_3423_3472    1_25
# 207           1  1_3472_3482    1_25
# 208           1  1_3482_3512    1_25
# 209           1  1_3512_3540    1_25
#
#                                               sentence  section_nr  \
# 200  Plotting a significant interaction effect help...           8
# 201  ) END_CITE   CITE_b0   provided some " golden ...           8
# 202  Beyond these , determining whether the simple ...           8
# 203                                  END_PARAGRAPH_TAG           8
# 204                                                              8
# 205                                START_PARAGRAPH_TAG           8
# 206  Second , if alternative measurements , methods...           8
# ...

# %%
sent.shape
# Out:
# (28655736, 10)
