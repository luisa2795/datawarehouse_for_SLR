# %%
#import packages
import pandas as pd
import os

#define source directory
path='/home/muellerrol/causeminer2/reports/2021_11_09_103116_results'

#filenames of ontology stats-related files
ont_file='ontology_stats.csv'

#load data
ont=pd.read_csv(os.path.join(path,ont_file))

print(ont.shape)
print(ont.columns)
# Out:
# (17, 5)
# Index(['Root Entity', 'Label', 'Number of Entities', 'Number of Synonyms',
#        'Maximal Depth'],
#       dtype='object')

# %%
ont.head(17)
# Out:
#                        Root Entity              Label  Number of Entities  \
# 0                         IS topic              TOPIC                 210
# 1                research paradigm           PARADIGM                  14
# 2                    model element      MODEL_ELEMENT                  36
# 3                 geographic names             REGION                 326
# 4                  economic sector             SECTOR                 336
# 5                     company type       COMPANY_TYPE                   8
# 6                      participant       PARTICIPANTS                  15
# 7                level of analysis              LEVEL                  14
# 8                           theory             THEORY                 244
# 9             data analysis method    ANALYSIS_METHOD                 379
# 10                        sampling           SAMPLING                  28
# 11  information systems technology         TECHNOLOGY                 299
# ...
